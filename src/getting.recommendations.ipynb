# %% [markdown]
# # Unsupervised user explicit rating based recommendation system

# %%
# We can get the recommendation as a dataframe
# We select the name of the anime we want to find similitudes and Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
# Then the genre we want (or write "All")
# Then the type we want (or write "All")

from utils import recommend
recommend.create_df(recommend.unsupervised_user_based_recommender("Death Note"),"All","All",20)
# Out:
# c:\Users\christiandda\miniconda3\envs\stlit\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# These are the recommendations for similar animes to death note
#                                                name  \
#                    fullmetal alchemist  brotherhood
#                                         steins gate
#                              hunter x hunter  2011
#                                clannad  after story
#                  code geass  hangyaku no lelouch r2
#                       sen to chihiro no kamikakushi
#                             shigatsu wa kimi no uso
#                     code geass  hangyaku no lelouch
#                                        cowboy bebop
#                                       one punch man
#                                       mononoke hime
#                       suzumiya haruhi no shoushitsu
#                                            mushishi
#                          tengen toppa gurren lagann
#                               great teacher onizuka
#                                 howl no ugoku shiro
#                                fate zero 2nd season
#                             boku dake ga inai machi
#   ano hi mita hana no namae wo bokutachi wa mada...
#                                  shokugeki no souma
#
#                                               genre   type  episodes  rating
#   Action, Adventure, Drama, Fantasy, Magic, Mili...     TV      64.0    9.26
#                                    Sci-Fi, Thriller     TV      24.0    9.17
#             Action, Adventure, Shounen, Super Power     TV     148.0    9.13
#   Drama, Fantasy, Romance, Slice of Life, Supern...     TV      24.0    9.06
#   Action, Drama, Mecha, Military, Sci-Fi, Super ...     TV      25.0    8.98
#                      Adventure, Drama, Supernatural  Movie       1.0    8.93
#              Drama, Music, Romance, School, Shounen     TV      22.0    8.92
#   Action, Mecha, Military, School, Sci-Fi, Super...     TV      25.0    8.83
#     Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV      26.0    8.82
#   Action, Comedy, Parody, Sci-Fi, Seinen, Super ...     TV      12.0    8.82
#                          Action, Adventure, Fantasy  Movie       1.0    8.81
#   Comedy, Mystery, Romance, School, Sci-Fi, Supe...  Movie       1.0    8.81
#   Adventure, Fantasy, Historical, Mystery, Seine...     TV      26.0    8.78
#            Action, Adventure, Comedy, Mecha, Sci-Fi     TV      27.0    8.78
#       Comedy, Drama, School, Shounen, Slice of Life     TV      43.0    8.77
#                  Adventure, Drama, Fantasy, Romance  Movie       1.0    8.74
#             Action, Fantasy, Supernatural, Thriller     TV      12.0    8.73
#        Mystery, Psychological, Seinen, Supernatural     TV      12.0    8.65
#                  Drama, Slice of Life, Supernatural     TV      11.0    8.62
#                              Ecchi, School, Shounen     TV      24.0    8.61

# %%
# We can get the recommendation as a dictionary
# We select the name of the anime we want to find similitudes and Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
# Then the genre we want (or write "All")
# Then the type we want (or write "All")

from utils import recommend
recommend.create_dict(recommend.unsupervised_user_based_recommender("Monster"),"All","All",30)
# Out:
# These are the recommendations for similar animes to monster
# [{'name': 'ginga eiyuu densetsu',
#   'genre': 'Drama, Military, Sci-Fi, Space',
#   'type': 'OVA',
#   'episodes': 110.0,
#   'rating': 9.11},
#  {'name': 'romeo no aoi sora',
#   'genre': 'Adventure, Drama, Historical, Slice of Life',
#   'type': 'TV',
#   'episodes': 33.0,
#   'rating': 8.47},
#  {'name': 'rose of versailles',
#   'genre': 'Adventure, Drama, Historical, Romance, Shoujo',
#   'type': 'TV',
#   'episodes': 40.0,
#   'rating': 8.4},
#  {'name': 'gyakkyou burai kaiji  hakairoku hen',
#   'genre': 'Game, Psychological, Seinen, Thriller',
#   'type': 'TV',
#   'episodes': 26.0,
#   'rating': 8.29},
#  {'name': 'ashita no joe',
#   'genre': 'Drama, Sports',
#   'type': 'TV',
#   'episodes': 79.0,
#   'rating': 8.22},
#  {'name': 'ginga eiyuu densetsu  arata naru tatakai no overture',
#   'genre': 'Action, Drama, Military, Sci-Fi, Space',
#   'type': 'Movie',
#   'episodes': 1.0,
#   'rating': 8.21},
#  {'name': 'ginga eiyuu densetsu gaiden  senoku no hoshi  senoku no hikari',
#   'genre': 'Action, Military, Sci-Fi, Space',
#   'type': 'OVA',
#   'episodes': 24.0,
#   'rating': 8.2},
#  {'name': 'hanada shounen shi',
#   'genre': 'Comedy, Drama, Slice of Life, Supernatural',
#   'type': 'TV',
#   'episodes': 25.0,
#   'rating': 8.16},
#  {'name': 'mirai shounen conan',
#   'genre': 'Adventure, Drama, Sci-Fi',
#   'type': 'TV',
#   'episodes': 26.0,
#   'rating': 8.16},
#  {'name': 'touch',
#   'genre': 'Drama, Romance, School, Shounen, Slice of Life, Sports',
#   'type': 'TV',
#   'episodes': 101.0,
#   'rating': 8.16},
#  {'name': 'city hunter 2',
#   'genre': 'Action, Comedy, Mystery, Shounen',
#   'type': 'TV',
#   'episodes': 63.0,
#   'rating': 8.12},
#  {'name': 'ginga eiyuu densetsu gaiden  rasen meikyuu',
#   'genre': 'Drama, Military, Sci-Fi, Space',
#   'type': 'OVA',
#   'episodes': 28.0,
#   'rating': 8.1},
#  {'name': 'ginga eiyuu densetsu  waga yuku wa hoshi no taikai',
#   'genre': 'Action, Historical, Military, Sci-Fi, Space',
#   'type': 'Movie',
#   'episodes': 1.0,
#   'rating': 8.09},
#  {'name': 'flanders no inu  movie ',
#   'genre': 'Drama, Historical',
#   'type': 'Movie',
#   'episodes': 1.0,
#   'rating': 8.05},
#  {'name': 'takarajima',
#   'genre': 'Adventure, Drama, Historical, Mystery',
#   'type': 'TV',
#   'episodes': 26.0,
#   'rating': 8.04},
#  {'name': 'touhai densetsu akagi  yami ni maiorita tensai',
#   'genre': 'Game, Psychological, Seinen, Thriller',
#   'type': 'TV',
#   'episodes': 26.0,
#   'rating': 8.02},
#  {'name': 'city hunter',
#   'genre': 'Action, Comedy, Mystery, Shounen',
#   'type': 'TV',
#   'episodes': 51.0,
#   'rating': 8.0},
#  {'name': 'ushiro no shoumen daare',
#   'genre': 'Drama, Historical',
#   'type': 'Movie',
#   'episodes': 1.0,
#   'rating': 7.99},
#  {'name': 'kindaichi shounen no jikenbo  tv ',
#   'genre': 'Mystery, Shounen',
#   'type': 'TV',
#   'episodes': 148.0,
#   'rating': 7.96},
#  {'name': 'city hunter 3',
#   'genre': 'Action, Comedy, Mystery, Shounen',
#   'type': 'TV',
#   'episodes': 13.0,
#   'rating': 7.95},
#  {'name': 'city hunter   039 91',
#   'genre': 'Action, Comedy, Mystery, Shounen',
#   'type': 'TV',
#   'episodes': 13.0,
#   'rating': 7.91},
#  {'name': 'master keaton ova',
#   'genre': 'Adventure, Mystery',
#   'type': 'OVA',
#   'episodes': 15.0,
#   'rating': 7.91},
#  {'name': 'ie naki ko',
#   'genre': 'Adventure, Drama, Historical, Kids, Slice of Life',
#   'type': 'TV',
#   'episodes': 51.0,
#   'rating': 7.9},
#  {'name': 'oniisama e   ',
#   'genre': 'Drama, School, Shoujo, Shoujo Ai',
#   'type': 'TV',
#   'episodes': 39.0,
#   'rating': 7.88},
#  {'name': 'soukou kihei votoms',
#   'genre': 'Action, Drama, Mecha, Military, Sci-Fi, Space',
#   'type': 'TV',
#   'episodes': 52.0,
#   'rating': 7.87},
#  {'name': 'ima  soko ni iru boku',
#   'genre': 'Adventure, Drama, Fantasy, Military, Sci-Fi',
#   'type': 'TV',
#   'episodes': 13.0,
#   'rating': 7.81},
#  {'name': 'texhnolyze',
#   'genre': 'Action, Drama, Psychological, Sci-Fi',
#   'type': 'TV',
#   'episodes': 22.0,
#   'rating': 7.78},
#  {'name': 'master keaton',
#   'genre': 'Adventure, Mystery',
#   'type': 'TV',
#   'episodes': 24.0,
#   'rating': 7.76},
#  {'name': 'ie naki ko remi specials',
#   'genre': 'Adventure, Drama',
#   'type': 'Special',
#   'episodes': 3.0,
#   'rating': 7.72},
#  {'name': 'ike  ina chuu takkyuubu',
#   'genre': 'Comedy, Ecchi, School, Sports',
#   'type': 'TV',
#   'episodes': 26.0,
#   'rating': 7.7}]

# %% [markdown]
# # Unsupervised content based recommendation system

# %%
# We can get the recommendation as a dataframe
# We selec the name of the anime we want to find similitudes
# Then the genre we want (or write "All")
# Then the type we want (or write "All")
# Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)

from utils import recommend
recommend.create_df(recommend.print_similar_animes("Naruti"),"All","All",20)
# Out:
# I guess you misspelled the name
#  Are you looking similitudes for the anime named naruto?
# Here are the recommendations:
#                                 name  \
#               hunter x hunter  2011
#   ansatsu kyoushitsu  tv  2nd season
#                      hunter x hunter
#               katekyo hitman reborn
#                boku no hero academia
#                        dragon ball z
#      shijou saikyou no deshi kenichi
#                         kill la kill
#              ansatsu kyoushitsu  tv
#                           d gray man
#                          dragon ball
#                        city hunter 2
#                    tiger  amp  bunny
#                         eyeshield 21
#                     yakitate   japan
#             boruto  naruto the movie
#                    d gray man hallow
#               dragon ball kai  2014
#                          city hunter
#                     lupin iii  2015
#
#                                               genre   type  episodes  rating
#             Action, Adventure, Shounen, Super Power     TV     148.0    9.13
#                     Action, Comedy, School, Shounen     TV      25.0    8.68
#             Action, Adventure, Shounen, Super Power     TV      62.0    8.48
#                Action, Comedy, Shounen, Super Power     TV     203.0    8.37
#        Action, Comedy, School, Shounen, Super Power     TV      13.0    8.36
#   Action, Adventure, Comedy, Fantasy, Martial Ar...     TV     291.0    8.32
#       Action, Comedy, Martial Arts, School, Shounen     TV      50.0    8.25
#                 Action, Comedy, School, Super Power     TV      24.0    8.23
#                     Action, Comedy, School, Shounen     TV      22.0    8.20
#                  Action, Adventure, Comedy, Shounen     TV     103.0    8.20
#   Adventure, Comedy, Fantasy, Martial Arts, Shou...     TV     153.0    8.16
#                    Action, Comedy, Mystery, Shounen     TV      63.0    8.12
#                Action, Comedy, Mystery, Super Power     TV      25.0    8.12
#                     Action, Comedy, Shounen, Sports     TV     145.0    8.08
#                                     Comedy, Shounen     TV      69.0    8.05
#   Action, Comedy, Martial Arts, Shounen, Super P...  Movie       1.0    8.03
#                Action, Demons, Shounen, Super Power     TV      13.0    8.01
#   Action, Adventure, Comedy, Fantasy, Martial Ar...     TV      61.0    8.01
#                    Action, Comedy, Mystery, Shounen     TV      51.0    8.00
#                  Action, Adventure, Comedy, Shounen     TV      24.0    7.97

# %%
# We can get the recommendation as a dictionary
# We selec the name of the anime we want to find similitudes
# Then the genre we want (or write "All")
# Then the type we want (or write "All")
# Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)

from utils import recommend
recommend.create_dict(recommend.print_similar_animes("Monster"),"Supernatural","All",10)
# Out:
# I guess you misspelled the name
#  Are you looking similitudes for the anime named monster?
# Here are the recommendations:
# [{'name': 'death note',
#   'genre': 'Mystery, Police, Psychological, Supernatural, Thriller',
#   'type': 'TV',
#   'episodes': 37.0,
#   'rating': 8.71},
#  {'name': 'boku dake ga inai machi',
#   'genre': 'Mystery, Psychological, Seinen, Supernatural',
#   'type': 'TV',
#   'episodes': 12.0,
#   'rating': 8.65},
#  {'name': 'shinsekai yori',
#   'genre': 'Drama, Horror, Mystery, Sci-Fi, Supernatural',
#   'type': 'TV',
#   'episodes': 25.0,
#   'rating': 8.53},
#  {'name': 'higurashi no naku koro ni kai',
#   'genre': 'Mystery, Psychological, Supernatural, Thriller',
#   'type': 'TV',
#   'episodes': 24.0,
#   'rating': 8.41},
#  {'name': 'bungou stray dogs 2nd season',
#   'genre': 'Mystery, Seinen, Supernatural',
#   'type': 'TV',
#   'episodes': 12.0,
#   'rating': 8.39},
#  {'name': 'xxxholic kei',
#   'genre': 'Comedy, Drama, Mystery, Psychological, Supernatural',
#   'type': 'TV',
#   'episodes': 13.0,
#   'rating': 8.34},
#  {'name': 'gankutsuou',
#   'genre': 'Drama, Mystery, Sci-Fi, Supernatural, Thriller',
#   'type': 'TV',
#   'episodes': 24.0,
#   'rating': 8.27},
#  {'name': 'higurashi no naku koro ni',
#   'genre': 'Horror, Mystery, Psychological, Supernatural, Thriller',
#   'type': 'TV',
#   'episodes': 26.0,
#   'rating': 8.17},
#  {'name': 'ajin 2nd season',
#   'genre': 'Action, Horror, Mystery, Seinen, Supernatural',
#   'type': 'TV',
#   'episodes': 13.0,
#   'rating': 8.12},
#  {'name': 'xxxholic',
#   'genre': 'Comedy, Drama, Mystery, Psychological, Supernatural',
#   'type': 'TV',
#   'episodes': 24.0,
#   'rating': 8.11}]

# %% [markdown]
# # Supervised user based collaborative filtering

# %%
# We can get the recommendation as a dataframe
# We input the user ID for we want the recommendations
# Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
# Then the genre we want (or write "All")
# Then the type we want (or write "All")

from utils import recommend
recommend.df_recommendation(675,10,"All","All")
# Out:
#                                                name  \
#   Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
#                                      Kimi no Na wa.
#                                             Gintama
#                    Fullmetal Alchemist: Brotherhood
#                                Ginga Eiyuu Densetsu
#                                         Steins;Gate
#                              Hajime no Ippo: Rising
#                                       Gintama&#039;
#                                Clannad: After Story
#                              Hunter x Hunter (2011)
#
#                                               genre   type  Estimate_Score
#   Action, Comedy, Historical, Parody, Samurai, S...  Movie        9.400277
#                Drama, Romance, School, Supernatural  Movie        9.308180
#   Action, Comedy, Historical, Parody, Samurai, S...     TV        9.298788
#   Action, Adventure, Drama, Fantasy, Magic, Mili...     TV        9.243445
#                      Drama, Military, Sci-Fi, Space    OVA        9.237419
#                                    Sci-Fi, Thriller     TV        9.145566
#                      Comedy, Drama, Shounen, Sports     TV        9.125941
#   Action, Comedy, Historical, Parody, Samurai, S...     TV        9.088100
#   Drama, Fantasy, Romance, Slice of Life, Supern...     TV        9.015971
#             Action, Adventure, Shounen, Super Power     TV        9.011210

# %%
# We can get the recommendation as a dictionary
# We input the user ID for we want the recommendations
# Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
# Then the genre we want (or write "All")
# Then the type we want (or write "All")

from utils import recommend
recommend.dict_recommendation(25000,10,"Supernatural","All")
# Out:
# [{'name': 'Kimi no Na wa.',
#   'genre': 'Drama, Romance, School, Supernatural',
#   'type': 'Movie',
#   'Estimate_Score': 9.267559570322923},
#  {'name': 'Clannad: After Story',
#   'genre': 'Drama, Fantasy, Romance, Slice of Life, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.993296165169316},
#  {'name': 'Natsume Yuujinchou San',
#   'genre': 'Drama, Fantasy, Shoujo, Slice of Life, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.910646955842989},
#  {'name': 'Hellsing Ultimate',
#   'genre': 'Action, Horror, Military, Seinen, Supernatural, Vampire',
#   'type': 'OVA',
#   'Estimate_Score': 8.910069750476053},
#  {'name': 'Suzumiya Haruhi no Shoushitsu',
#   'genre': 'Comedy, Mystery, Romance, School, Sci-Fi, Supernatural',
#   'type': 'Movie',
#   'Estimate_Score': 8.857521936987201},
#  {'name': 'Mushishi',
#   'genre': 'Adventure, Fantasy, Historical, Mystery, Seinen, Slice of Life, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.824964619339559},
#  {'name': 'Natsume Yuujinchou Shi',
#   'genre': 'Drama, Fantasy, Shoujo, Slice of Life, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.787646291264451},
#  {'name': 'Mushishi Zoku Shou: Suzu no Shizuku',
#   'genre': 'Adventure, Fantasy, Historical, Mystery, Seinen, Slice of Life, Supernatural',
#   'type': 'Movie',
#   'Estimate_Score': 8.772512230181343},
#  {'name': 'Mushishi Special: Hihamukage',
#   'genre': 'Adventure, Fantasy, Historical, Mystery, Seinen, Slice of Life, Supernatural',
#   'type': 'Special',
#   'Estimate_Score': 8.767243561309826},
#  {'name': 'Shinsekai yori',
#   'genre': 'Drama, Horror, Mystery, Sci-Fi, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.752297568225664}]

# %%
#os.remove(processed_data + "/" + "features_user_based_unsupervised.pkl")
#os.remove(processed_data + "/" + "pivot_user_based_unsupervised.pkl")
