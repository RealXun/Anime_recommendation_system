# %% [markdown]
# # Unsupervised user explicit rating based recommendation system

# %%
# We can get the recommendation as a dataframe
# We select the name of the anime we want to find similitudes and Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
# Then the genre we want (or write "All")
# Then the type we want (or write "All")

# from utils import recommend
# recommend.create_df(recommend.unsupervised_user_based_recommender("Death Note"),"All","All",20)
# Out:
# c:\Users\christiandda\miniconda3\envs\stlit\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# These are the recommendations for similar animes to death note
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       1 # We can get the recommendation as a dataframe
#       2 # We select the name of the anime we want to find similitudes and Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
#       3 # Then the genre we want (or write "All")
#       4 # Then the type we want (or write "All")
#       6 from utils import recommend
# ----> 7 recommend.create_df(recommend.unsupervised_user_based_recommender("Death Note"),"All","All",20)
#
# File c:\Users\christiandda\Documents\Github\Anime_recommendation_system\src\utils\recommend.py:261, in unsupervised_user_based_recommender(movie_user_likes, n)
#     259 if distance_score == 100:
#     260     print('These are the recommendations for similar animes to '+'\033'+str(closest_title)+'\033'+'','\n')
# --> 261     return reco(lowertittle,n,pivot_df_try)
#     262 # When a user makes misspellings
#     263 else:
#     264     print('I guess you misspelled the name\n\nAre you looking similitudes for the anime named '+'\033'+str(closest_title)+'\033'+'?','\n' + '\nHere are the recommendations:\n')
#
# File c:\Users\christiandda\Documents\Github\Anime_recommendation_system\src\utils\recommend.py:234, in reco(name, n, df)
#     232 pivot_df = joblib.load(processed_data + "/" +"pivot_user_based_unsupervised.pkl")
#     233 indl = from_title_to_index(name,df)
# --> 234 distances, indices = model_knn.kneighbors(pivot_df.iloc[indl,:].values.reshape(1, -1), n_neighbors = n+1)
#     235 names_list = []
#     236 for i in range(1, n+1):
#
# File c:\Users\christiandda\miniconda3\envs\stlit\lib\site-packages\sklearn\neighbors\_base.py:806, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     804         X = _check_precomputed(X)
#     805     else:
# --> 806         X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#     808 n_samples_fit = self.n_samples_fit_
#     809 if n_neighbors > n_samples_fit:
#
# File c:\Users\christiandda\miniconda3\envs\stlit\lib\site-packages\sklearn\base.py:569, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
# --> 569     self._check_n_features(X, reset=reset)
#     571 return out
#
# File c:\Users\christiandda\miniconda3\envs\stlit\lib\site-packages\sklearn\base.py:370, in BaseEstimator._check_n_features(self, X, reset)
#     367     return
#     369 if n_features != self.n_features_in_:
# --> 370     raise ValueError(
#     371         f"X has {n_features} features, but {self.__class__.__name__} "
#     372         f"is expecting {self.n_features_in_} features as input."
#     373     )
#
# ValueError: X has 8713 features, but NearestNeighbors is expecting 8551 features as input.

# %%
# We can get the recommendation as a dictionary
# We select the name of the anime we want to find similitudes and Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
# Then the genre we want (or write "All")
# Then the type we want (or write "All")

from utils import recommend
recommend.create_dict(recommend.unsupervised_user_based_recommender("Bleach",5),"All","All")
# Out:
# These are the recommendations for similar animes to bleach
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 7
#       1 # We can get the recommendation as a dictionary
#       2 # We select the name of the anime we want to find similitudes and Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
#       3 # Then the genre we want (or write "All")
#       4 # Then the type we want (or write "All")
#       6 from utils import recommend
# ----> 7 recommend.create_dict(recommend.unsupervised_user_based_recommender("Bleach",5),"All","All")
#
# File c:\Users\christiandda\Documents\Github\Anime_recommendation_system\src\utils\recommend.py:261, in unsupervised_user_based_recommender(movie_user_likes, n)
#     259 if distance_score == 100:
#     260     print('These are the recommendations for similar animes to '+'\033'+str(closest_title)+'\033'+'','\n')
# --> 261     return reco(lowertittle,n,pivot_df_try)
#     262 # When a user makes misspellings
#     263 else:
#     264     print('I guess you misspelled the name\n\nAre you looking similitudes for the anime named '+'\033'+str(closest_title)+'\033'+'?','\n' + '\nHere are the recommendations:\n')
#
# File c:\Users\christiandda\Documents\Github\Anime_recommendation_system\src\utils\recommend.py:234, in reco(name, n, df)
#     232 pivot_df = joblib.load(processed_data + "/" +"pivot_user_based_unsupervised.pkl")
#     233 indl = from_title_to_index(name,df)
# --> 234 distances, indices = model_knn.kneighbors(pivot_df.iloc[indl,:].values.reshape(1, -1), n_neighbors = n+1)
#     235 names_list = []
#     236 for i in range(1, n+1):
#
# File c:\Users\christiandda\miniconda3\envs\stlit\lib\site-packages\sklearn\neighbors\_base.py:806, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     804         X = _check_precomputed(X)
#     805     else:
# --> 806         X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#     808 n_samples_fit = self.n_samples_fit_
#     809 if n_neighbors > n_samples_fit:
#
# File c:\Users\christiandda\miniconda3\envs\stlit\lib\site-packages\sklearn\base.py:569, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
# --> 569     self._check_n_features(X, reset=reset)
#     571 return out
#
# File c:\Users\christiandda\miniconda3\envs\stlit\lib\site-packages\sklearn\base.py:370, in BaseEstimator._check_n_features(self, X, reset)
#     367     return
#     369 if n_features != self.n_features_in_:
# --> 370     raise ValueError(
#     371         f"X has {n_features} features, but {self.__class__.__name__} "
#     372         f"is expecting {self.n_features_in_} features as input."
#     373     )
#
# ValueError: X has 8713 features, but NearestNeighbors is expecting 8551 features as input.

# %% [markdown]
# # Unsupervised content based recommendation system

# %%
# We can get the recommendation as a dataframe
# We selec the name of the anime we want to find similitudes
# Then the genre we want (or write "All")
# Then the type we want (or write "All")
# Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)

#from utils import recommend
#recommend.create_df(recommend.print_similar_animes("Naruti"),"All","All",20)
# Out:
# I guess you misspelled the name
#  Are you looking similitudes for the anime named naruto?
# Here are the recommendations:
#                                 name  \
#               hunter x hunter  2011
#   ansatsu kyoushitsu  tv  2nd season
#                      hunter x hunter
#               katekyo hitman reborn
#                boku no hero academia
#                        dragon ball z
#      shijou saikyou no deshi kenichi
#                         kill la kill
#              ansatsu kyoushitsu  tv
#                           d gray man
#                          dragon ball
#                        city hunter 2
#                    tiger  amp  bunny
#                         eyeshield 21
#                     yakitate   japan
#             boruto  naruto the movie
#                    d gray man hallow
#               dragon ball kai  2014
#                          city hunter
#                     lupin iii  2015
#
#                                               genre   type  episodes  rating
#             Action, Adventure, Shounen, Super Power     TV     148.0    9.13
#                     Action, Comedy, School, Shounen     TV      25.0    8.68
#             Action, Adventure, Shounen, Super Power     TV      62.0    8.48
#                Action, Comedy, Shounen, Super Power     TV     203.0    8.37
#        Action, Comedy, School, Shounen, Super Power     TV      13.0    8.36
#   Action, Adventure, Comedy, Fantasy, Martial Ar...     TV     291.0    8.32
#       Action, Comedy, Martial Arts, School, Shounen     TV      50.0    8.25
#                 Action, Comedy, School, Super Power     TV      24.0    8.23
#                     Action, Comedy, School, Shounen     TV      22.0    8.20
#                  Action, Adventure, Comedy, Shounen     TV     103.0    8.20
#   Adventure, Comedy, Fantasy, Martial Arts, Shou...     TV     153.0    8.16
#                    Action, Comedy, Mystery, Shounen     TV      63.0    8.12
#                Action, Comedy, Mystery, Super Power     TV      25.0    8.12
#                     Action, Comedy, Shounen, Sports     TV     145.0    8.08
#                                     Comedy, Shounen     TV      69.0    8.05
#   Action, Comedy, Martial Arts, Shounen, Super P...  Movie       1.0    8.03
#                Action, Demons, Shounen, Super Power     TV      13.0    8.01
#   Action, Adventure, Comedy, Fantasy, Martial Ar...     TV      61.0    8.01
#                    Action, Comedy, Mystery, Shounen     TV      51.0    8.00
#                  Action, Adventure, Comedy, Shounen     TV      24.0    7.97

# %%
# We can get the recommendation as a dictionary
# We selec the name of the anime we want to find similitudes
# Then the genre we want (or write "All")
# Then the type we want (or write "All")
# Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)

from utils import recommend
recommend.create_dict(recommend.print_similar_animes("Monster"),"Supernatural","All",10)
# Out:
# I guess you misspelled the name
#  Are you looking similitudes for the anime named monster?
# Here are the recommendations:
# [{'name': 'beet the vandel buster',
#   'english_title': 'Bouken Ou Beet',
#   'japanses_title': '冒険王ビィト',
#   'genre': 'Adventure, Fantasy, Shounen, Supernatural',
#   'type': 'TV',
#   'source': 'Manga',
#   'duration': '23 min per ep',
#   'episodes': 52.0,
#   'rating': 'PG - Children',
#   'score': 6.94,
#   'rank': 4310.0,
#   'synopsis': "It is the dark century and the people are suffering under the rule of the devil, Vandel, who is able to manipulate monsters. The Vandel Busters are a group of people who hunt these devils, and among them, the Zenon Squad is known to be the strongest busters on the continent. A young boy, Beet, dreams of joining the Zenon Squad. However, one day, as a result of Beet's fault, the Zenon squad was defeated by the devil, Beltose. The five dying busters sacrificed their life power into their five weapons, Saiga. After giving their weapons to Beet, they passed away. Years have passed since then and the young Vandel Buster, Beet, begins his adventure to carry out the Zenon Squad's will to put an end to the dark century.",
#   'cover': 'https://cdn.myanimelist.net/images/anime/7/21569l.jpg'},
#  {'name': 'mahou sensei negima ',
#   'english_title': 'Mahou Sensei Negima!',
#   'japanses_title': '魔法先生 ネギま！',
#   'genre': 'Comedy, Ecchi, Fantasy, Harem, Magic, Romance, School, Shounen, Super Power, Supernatural',
#   'type': 'TV',
#   'source': 'Manga',
#   'duration': '23 min per ep',
#   'episodes': 26.0,
#   'rating': 'PG-13 - Teens 13 or older',
#   'score': 6.94,
#   'rank': 4326.0,
#   'synopsis': '10-year-old Negi Springfield is a wizard-in-training, and needs only to pass one more test in order to become a Master Wizard. Unfortunately, his final task is a bizarre one—to become a English teacher at an all-females boarding school. As soon as he arrives, he completely embarrasses one of his students, Asuna Kagurazaka, and replaces the teacher she loves, which garners her hatred. To make matters worse, Asuna learns that Negi is a wizard, and promises to tell unless he helps her out. But unfortunately, circumstances force them to work together to do many things, from fighting evil wizards to helping the class pass their final exam, with a lot of humor, magic, and romances thrown in.\n\n(Source: ANN, edited)',
#   'cover': 'https://cdn.myanimelist.net/images/anime/12/89535l.jpg'},
#  {'name': 'gilgamesh',
#   'english_title': 'Gilgamesh',
#   'japanses_title': 'ギルガメッシュ',
#   'genre': 'Drama, Fantasy, Sci-Fi, Supernatural',
#   'type': 'TV',
#   'source': 'Manga',
#   'duration': '23 min per ep',
#   'episodes': 26.0,
#   'rating': 'R - 17+ (violence & profanity)',
#   'score': 6.63,
#   'rank': 5893.0,
#   'synopsis': 'In an attempt to gather information on immortality, scientists from around the world have assembled to study "Heaven\'s Gate"—the tomb turned laboratory of the mythical king Gilgamesh. But soon enough, the research is deemed unethical and all planned work comes to a halt. However, a group of terrorists pay this no thought and storm into Heaven\'s Gate, ultimately causing an explosion that leads to the collapse of the advanced information civilization.\n\nMany years after the incident, the siblings Tatsuya and Kiyoko Madoka are on the run from thugs. Yet this seems to be the least of their worries as they find themselves in the midst of a war between two powerful cryptic factions. With both groups claiming to fight for the betterment of society, Tatsuya and Kiyoko will have to find a way to decide who to trust.\n\n[Written by MAL Rewrite]',
#   'cover': 'https://cdn.myanimelist.net/images/anime/13/6640l.jpg'},
#  {'name': 'one  kagayaku kisetsu e',
#   'english_title': 'One: Kagayaku Kisetsu e',
#   'japanses_title': 'ONE ～輝く季節へ～',
#   'genre': 'Drama, Supernatural',
#   'type': 'OVA',
#   'source': 'Visual novel',
#   'duration': '27 min per ep',
#   'episodes': 4.0,
#   'rating': 'PG-13 - Teens 13 or older',
#   'score': 5.05,
#   'rank': 12896.0,
#   'synopsis': "Orihara Kouhei returns to his town after a long disappearance to fullfil the promises he made to several girls in his childhood. He suffered from memory loss, and carries a tragic past. An strange ambience surrounds the OVA...It's almost like a dream, like memories from the past trying to come together in one piece but without being able to...\n\n(Source: ANN)",
#   'cover': 'https://cdn.myanimelist.net/images/anime/5/25086l.jpg'},
#  {'name': 'naisho no tsubomi',
#   'english_title': 'Naisho no Tsubomi',
#   'japanses_title': 'ないしょのつぼみ',
#   'genre': 'Kids, Romance, School, Shoujo, Slice of Life, Supernatural',
#   'type': 'OVA',
#   'source': 'Manga',
#   'duration': '27 min per ep',
#   'episodes': 3.0,
#   'rating': 'PG - Children',
#   'score': 6.51,
#   'rank': 6567.0,
#   'synopsis': "Tsubomi Tachibana is a fifth grader dealing with rather sensitive issues such as her mother's pregnancy, her first period and the strange feelings she has started to get when she has been around boys.\n\n(Source: ANN)",
#   'cover': 'https://cdn.myanimelist.net/images/anime/3/19981l.jpg'},
#  {'name': 'natsume yuujinchou',
#   'english_title': 'Natsume Yuujinchou',
#   'japanses_title': '夏目友人帳',
#   'genre': 'Drama, Fantasy, Shoujo, Slice of Life, Supernatural',
#   'type': 'TV',
#   'source': 'Manga',
#   'duration': '24 min per ep',
#   'episodes': 13.0,
#   'rating': 'PG-13 - Teens 13 or older',
#   'score': 8.31,
#   'rank': 231.0,
#   'synopsis': "Due to an unusual ability to see strange creatures called youkai, Takashi Natsume has never fit in. Passed around from one foster home to another, he was left isolated and lonely. Over time, he has accepted that no one would ever believe him and has closed himself off to his current caretakers and classmates.\n\nWhen Natsume accidentally breaks an intangible barrier, he frees Madara—a mighty spirit in the form of a lucky cat. Madara notices that Natsume bears a remarkable resemblance to his late grandmother Reiko Natsume, an outcast girl who became known across the youkai world for creating the Book of Friends. It is now in Natsume's possession, along with its power to call upon the written names of the youkai Reiko had defeated. \n\nWith no interest in its powers, Natsume decides to keep the book for the sake of his grandmother's memories and to protect it from scheming youkai. Therefore, he makes a deal with Madara: he will hand him the book once his time is up, and in turn, Madara will act as Natsume's unofficial bodyguard, nicknamed Nyanko-sensei. With his newfound goal of freeing those Reiko had sealed, Natsume's relationship with both youkai and humans slowly begins to improve.\n\n[Written by MAL Rewrite]",
#   'cover': 'https://cdn.myanimelist.net/images/anime/1681/108439l.jpg'},
#  {'name': 'kuroshitsuji',
#   'english_title': 'Kuroshitsuji',
#   'japanses_title': '黒執事',
#   'genre': 'Action, Comedy, Demons, Fantasy, Historical, Shounen, Supernatural',
#   'type': 'TV',
#   'source': 'Manga',
#   'duration': '24 min per ep',
#   'episodes': 24.0,
#   'rating': 'R - 17+ (violence & profanity)',
#   'score': 7.67,
#   'rank': 1204.0,
#   'synopsis': 'Young Ciel Phantomhive is known as "the Queen\'s Guard Dog," taking care of the many unsettling events that occur in Victorian England for Her Majesty. Aided by Sebastian Michaelis, his loyal butler with seemingly inhuman abilities, Ciel uses whatever means necessary to get the job done. But is there more to this black-clad butler than meets the eye?\n\nIn Ciel\'s past lies a secret tragedy that enveloped him in perennial darkness—during one of his bleakest moments, he formed a contract with Sebastian, a demon, bargaining his soul in exchange for vengeance upon those who wronged him. Today, not only is Sebastian one hell of a butler, but he is also the perfect servant to carry out his master\'s orders—all the while anticipating the delicious meal he will eventually make of Ciel\'s soul. As the two work to unravel the mystery behind Ciel\'s chain of misfortunes, a bond forms between them that neither heaven nor hell can tear apart.\n\n[Written by MAL Rewrite]',
#   'cover': 'https://cdn.myanimelist.net/images/anime/5/27013l.jpg'},
#  {'name': 'inuyasha  kanketsu hen',
#   'english_title': 'InuYasha: Kanketsu-hen',
#   'japanses_title': '犬夜叉 完結編',
#   'genre': 'Action, Adventure, Comedy, Demons, Fantasy, Magic, Romance, Shounen, Supernatural',
#   'type': 'TV',
#   'source': 'Manga',
#   'duration': '24 min per ep',
#   'episodes': 26.0,
#   'rating': 'PG-13 - Teens 13 or older',
#   'score': 8.2,
#   'rank': 348.0,
#   'synopsis': 'Thwarted again by Naraku, Inuyasha, Kagome Higurashi, and their friends must continue their hunt for the few remaining Shikon Jewel shards, lest they fully form into a corrupted jewel at the hands of Naraku. But Naraku has plans of his own to acquire them, and will destroy anyone and anything standing in his way—even his own underlings.\n\nThe persistent, unyielding danger posed by Naraku forces Sango and Miroku to decide what is most important to them—each other or their duty in battle. Meanwhile, Inuyasha must decide whether his heart lies with Kikyou or Kagome, before fate decides for him. Amid the race to find the shards, Inuyasha and his brother Sesshoumaru must also resolve their feud and cooperate for their final confrontation with Naraku, as it is a battle they must win in order to put a stop to his evil and cruelty once and for all.\n\n[Written by MAL Rewrite]',
#   'cover': 'https://cdn.myanimelist.net/images/anime/7/75570l.jpg'},
#  {'name': 'kataku',
#   'english_title': 'Kataku',
#   'japanses_title': '火宅',
#   'genre': 'Demons, Historical, Supernatural',
#   'type': 'Movie',
#   'source': 'Other',
#   'duration': '19 min',
#   'episodes': 1.0,
#   'rating': 'PG-13 - Teens 13 or older',
#   'score': 6.0,
#   'rank': 9501.0,
#   'synopsis': 'Many years ago, a young woman named Unai-Otome lived in the village of Ikuta. As she was beautiful it was no surprise that she had two suitors, both deeply in love with her. The girl was torn apart over which one to choose. In her desperation she chose a third option - taking her own life. Although her intentions were absolutely pure, not even in death did she find the solace she desired. Many decades later, a pilgrim walking by her grave meets a beautiful young woman and her story once again rises from the depths of time.... With a plot based on a classic play of Noh traditional theatre, the film presents the peak of Kawamoto’s mastery thanks to its expert mediation of the absurdity of the human condition.\n\n(Source: Karlovy Vary International Film Festival)',
#   'cover': 'https://cdn.myanimelist.net/images/anime/7/81216l.jpg'},
#  {'name': 'akuma kun  youkoso akuma land e  ',
#   'english_title': 'Akuma-kun: Youkoso Akuma Land e!!',
#   'japanses_title': '悪魔くん ようこそ悪魔ランドへ!!',
#   'genre': 'Adventure, Fantasy, Horror, Magic, Supernatural',
#   'type': 'Movie',
#   'source': 'Unknown',
#   'duration': '25 min',
#   'episodes': 1.0,
#   'rating': 'G - All Ages',
#   'score': 5.86,
#   'rank': 10118.0,
#   'synopsis': 'No synopsis has been added for this series yet.\n\nClick here to update this information.',
#   'cover': 'https://cdn.myanimelist.net/images/anime/12/21277l.jpg'}]

# %% [markdown]
# # Supervised user based collaborative filtering

# %%
# We can get the recommendation as a dataframe
# We input the user ID for we want the recommendations
# Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
# Then the genre we want (or write "All")
# Then the type we want (or write "All")

from utils import recommend
recommend.df_recommendation(675,10,"All","All")
# Out:
#                                                name  \
#   Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
#                                      Kimi no Na wa.
#                                             Gintama
#                    Fullmetal Alchemist: Brotherhood
#                                Ginga Eiyuu Densetsu
#                                         Steins;Gate
#                              Hajime no Ippo: Rising
#                                       Gintama&#039;
#                                Clannad: After Story
#                              Hunter x Hunter (2011)
#
#                                               genre   type  Estimate_Score
#   Action, Comedy, Historical, Parody, Samurai, S...  Movie        9.400277
#                Drama, Romance, School, Supernatural  Movie        9.308180
#   Action, Comedy, Historical, Parody, Samurai, S...     TV        9.298788
#   Action, Adventure, Drama, Fantasy, Magic, Mili...     TV        9.243445
#                      Drama, Military, Sci-Fi, Space    OVA        9.237419
#                                    Sci-Fi, Thriller     TV        9.145566
#                      Comedy, Drama, Shounen, Sports     TV        9.125941
#   Action, Comedy, Historical, Parody, Samurai, S...     TV        9.088100
#   Drama, Fantasy, Romance, Slice of Life, Supern...     TV        9.015971
#             Action, Adventure, Shounen, Super Power     TV        9.011210

# %%
# We can get the recommendation as a dictionary
# We input the user ID for we want the recommendations
# Then the number of suggestions we have(we might get less if there not so many o none if there is no matches)
# Then the genre we want (or write "All")
# Then the type we want (or write "All")

from utils import recommend
recommend.dict_recommendation(25000,10,"Supernatural","All")
# Out:
# [{'name': 'Kimi no Na wa.',
#   'genre': 'Drama, Romance, School, Supernatural',
#   'type': 'Movie',
#   'Estimate_Score': 9.267559570322923},
#  {'name': 'Clannad: After Story',
#   'genre': 'Drama, Fantasy, Romance, Slice of Life, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.993296165169316},
#  {'name': 'Natsume Yuujinchou San',
#   'genre': 'Drama, Fantasy, Shoujo, Slice of Life, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.910646955842989},
#  {'name': 'Hellsing Ultimate',
#   'genre': 'Action, Horror, Military, Seinen, Supernatural, Vampire',
#   'type': 'OVA',
#   'Estimate_Score': 8.910069750476053},
#  {'name': 'Suzumiya Haruhi no Shoushitsu',
#   'genre': 'Comedy, Mystery, Romance, School, Sci-Fi, Supernatural',
#   'type': 'Movie',
#   'Estimate_Score': 8.857521936987201},
#  {'name': 'Mushishi',
#   'genre': 'Adventure, Fantasy, Historical, Mystery, Seinen, Slice of Life, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.824964619339559},
#  {'name': 'Natsume Yuujinchou Shi',
#   'genre': 'Drama, Fantasy, Shoujo, Slice of Life, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.787646291264451},
#  {'name': 'Mushishi Zoku Shou: Suzu no Shizuku',
#   'genre': 'Adventure, Fantasy, Historical, Mystery, Seinen, Slice of Life, Supernatural',
#   'type': 'Movie',
#   'Estimate_Score': 8.772512230181343},
#  {'name': 'Mushishi Special: Hihamukage',
#   'genre': 'Adventure, Fantasy, Historical, Mystery, Seinen, Slice of Life, Supernatural',
#   'type': 'Special',
#   'Estimate_Score': 8.767243561309826},
#  {'name': 'Shinsekai yori',
#   'genre': 'Drama, Horror, Mystery, Sci-Fi, Supernatural',
#   'type': 'TV',
#   'Estimate_Score': 8.752297568225664}]

# %%
#os.remove(processed_data + "/" + "features_user_based_unsupervised.pkl")
#os.remove(processed_data + "/" + "pivot_user_based_unsupervised.pkl")
